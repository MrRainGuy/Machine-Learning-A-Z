# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
polyf = PolynomialFeatures(degree=5)
X_poly = polyf.fit_transform(X)
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = "red")
plt.plot(X, lin_reg.predict(X))
plt.plot(X_grid, poly_reg.predict(polyf.fit_transform(X_grid)))
plt.title("Polynomial Regression and Linear Regression")
# Out:
# Text(0.5, 1.0, 'Polynomial Regression and Linear Regression')
